# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="hospital_db"
)

print("Connected to MySQL successfully!")

cursor = db.cursor()

cursor.execute("SELECT * FROM doctors")

rows = cursor.fetchall()
for row in rows:
    print(row)

cursor.close()
db.close()
# Out:
# Connected to MySQL successfully!
# (1, 'dr.kumar', 'cardiologist', '90000875555')
# (2, 'dr.viji', 'dermatologist', '5678935555')
# (3, 'dr.gopikarun', 'neurologist', '908778906')

# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="hospital_db"
)

cursor = db.cursor()

query = """
SELECT b.bill_id, p.name, t.diagnosis, b.amount, b.status
FROM billing b
JOIN treatments t ON b.treatment_id = t.treatment_id
JOIN appointments a ON t.appointment_id = a.appointment_id
JOIN patients p ON a.patient_id = p.patient_id;
"""

cursor.execute(query)

records = cursor.fetchall()

print("\n--- BILLING DETAILS ---\n")
for row in records:
    print(f"Bill ID: {row[0]}")
    print(f"Patient Name: {row[1]}")
    print(f"Diagnosis: {row[2]}")
    print(f"Amount: {row[3]}")
    print(f"Status: {row[4]}")
    print("------------------------")

cursor.close()
db.close()
# Out:
# --- BILLING DETAILS ---
#
# Bill ID: 1
# Patient Name: Arun
# Diagnosis: chest pain
# Amount: 1500.00
# Status: paid
# ------------------------
# Bill ID: 2
# Patient Name: priya
# Diagnosis: skin allergy
# Amount: 800.00
# Status: pending
# ------------------------
# Bill ID: 3
# Patient Name: karan
# Diagnosis: migraine
# Amount: 1200.00
# Status: paid
# ------------------------
# Bill ID: 4
# Patient Name: meena
# Diagnosis: high bp
# Amount: 2000.00
# Status: pending
# ------------------------

# %%
import mysql.connector

# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="hospital_db"
)

cursor = conn.cursor()


# Query: Billing + Treatments + Appointments + Patients
query1 = """
SELECT b.bill_id, p.name, t.diagnosis, b.amount, b.status
FROM billing b
JOIN treatments t ON b.treatment_id = t.treatment_id
JOIN appointments a ON t.appointment_id = a.appointment_id
JOIN patients p ON a.patient_id = p.patient_id;
"""

cursor.execute(query1)
results1 = cursor.fetchall()

print("\n--- BILL REPORT ---")
for row in results1:
    print(row)

# 2️⃣ Query: Doctors & Total Appointments
query2 = """
SELECT d.name, COUNT(a.appointment_id) AS total_appointments
FROM doctors d
LEFT JOIN appointments a ON d.doctor_id = a.doctor_id
GROUP BY d.name;
"""

cursor.execute(query2)
results2 = cursor.fetchall()

print("\n--- DOCTOR APPOINTMENTS ---")
for row in results2:
    print(row)

cursor.close()
conn.close()
# Out:
# --- BILL REPORT ---
# (1, 'Arun', 'chest pain', Decimal('1500.00'), 'paid')
# (2, 'priya', 'skin allergy', Decimal('800.00'), 'pending')
# (3, 'karan', 'migraine', Decimal('1200.00'), 'paid')
# (4, 'meena', 'high bp', Decimal('2000.00'), 'pending')
#
# --- DOCTOR APPOINTMENTS ---
# ('dr.kumar', 2)
# ('dr.viji', 1)
# ('dr.gopikarun', 1)
